# %% [markdown]
# # Data Manipulation with Pandas
#
# * Link: https://learn.datacamp.com/courses/data-manipulation-with-pandas

# %% [markdown]
# ## Course Descripton
#
# pandas is the world's most popular Python library, used for everything from data manipulation to data analysis. In this course, you'll learn how to manipulate DataFrames, as you extract, filter, and transform real-world datasets for analysis. Using pandas you’ll explore all the core data science concepts. Using real-world data, including Walmart sales figures and global temperature time series, you’ll learn how to import, clean, calculate statistics, and create visualizations—using pandas to add to the power of Python!

# %% [markdown]
# ## Course outline
#
# * **Chapter 1: DataFrames**
#   * Sorting and subsetting
#   * Creating new columns
# * **Chapter 2: Aggregating Data**
#   * Summary statistics
#   * Counting
#   * Grouped summary statistics
# * **Chapter 3: Slicing and Indexing Data**
#   * Subsetting using slicing
#   * Indexes and subsetting using indexes
# * **Chapter 4: Creating and Visualizing Data**
#   * Plotting
#   * Handling missing data
#   * Reading data into a DataFrame

# %% [markdown]
# # Chapter 1 - Transforming Data
#
# Let’s master the pandas basics. Learn how to inspect DataFrames and perform fundamental manipulations, including sorting rows, subsetting, and adding new columns.

# %% [markdown]
# ## Introducing DataFrames

# %% [markdown]
# ### Pandas
#
# * Used for data manipulation and data visualization
# * Pandas is built on Numpy and Matplotlib
# * Pandas is a very popular Python package
#   * Check: https://pypistats.org/packages/pandas
# * Pandas implement a very useful data strcuture called DataFrame, which is a tabular data structure, similar to an SQL table
#
# <br>
#
# * Pandas Philosophy
# > There should be one -- and preferably only one -- obvious way to do it. - The Zen of Python by Tim Peters, Item 13

# %% [markdown]
# ### Knowing a DataFrame

# %% [markdown]
# #### `.read_excel()`
#
# * Read an excel file

# %%
import pandas as pd

filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/dogs.xlsx'
dogs = pd.read_excel(filepath)

dogs
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 4      Max     Labrador  Black          59          29    2017-01-20
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# #### `.head()`
#
# * Exploring the top rows of a DataFrame

# %%
dogs.head()
# Out:
#       Name      Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella   Labrador  Brown          56          25    2013-07-01
# 1  Charlie     Poodle  Black          43          23    2016-09-16
# 2     Lucy  Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper  Schnauzer   Gray          49          17    2011-12-11
# 4      Max   Labrador  Black          59          29    2017-01-20

# %% [markdown]
# #### `.info()`

# %%
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           7 non-null      object
#  1   Breed          7 non-null      object
#  2   Color          7 non-null      object
#  3   Height(cm)     7 non-null      int64
#  4   Weight(kg)     7 non-null      int64
#  5   Date of Birth  7 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 464.0+ bytes

# %% [markdown]
# #### `.shape`

# %%
dogs.shape

# Shows (number of rows, number of columns)
# Out:
# (7, 6)

# %% [markdown]
# #### `.describe()`
#
# * Inform statistics about the data

# %%
dogs.describe()
# Out:
#        Height(cm)  Weight(kg)
# count    7.000000    7.000000
# mean    49.714286   27.428571
# std     17.960274   22.292429
# min     18.000000    2.000000
# 25%     44.500000   19.500000
# 50%     49.000000   23.000000
# 75%     57.500000   27.000000
# max     77.000000   74.000000

# %% [markdown]
# ### Componentes of a DataFrame

# %% [markdown]
# #### `.values`

# %%
dogs.values
# Out:
# array([['Bella', 'Labrador', 'Brown', 56, 25,
#         Timestamp('2013-07-01 00:00:00')],
#        ['Charlie', 'Poodle', 'Black', 43, 23,
#         Timestamp('2016-09-16 00:00:00')],
#        ['Lucy', 'Chow Chow', 'Brown', 46, 22,
#         Timestamp('2014-08-25 00:00:00')],
#        ['Cooper', 'Schnauzer', 'Gray', 49, 17,
#         Timestamp('2011-12-11 00:00:00')],
#        ['Max', 'Labrador', 'Black', 59, 29,
#         Timestamp('2017-01-20 00:00:00')],
#        ['Stella', 'Chihuahua', 'Tan', 18, 2,
#         Timestamp('2015-04-20 00:00:00')],
#        ['Bernie', 'St. Bernard', 'White', 77, 74,
#         Timestamp('2018-02-27 00:00:00')]], dtype=object)

# %% [markdown]
# #### `.columns`

# %%
dogs.columns
# Out:
# Index(['Name', 'Breed', 'Color', 'Height(cm)', 'Weight(kg)', 'Date of Birth'], dtype='object')

# %% [markdown]
# #### `.index`

# %%
dogs.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# ## Sorting and subsetting

# %% [markdown]
# ### Sorting with `.sort_values()`

# %%
dogs.sort_values('Weight(kg)')
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 4      Max     Labrador  Black          59          29    2017-01-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Sorting in descending order

# %%
dogs.sort_values('Weight(kg)', ascending=False)
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 6   Bernie  St. Bernard  White          77          74    2018-02-27
# 4      Max     Labrador  Black          59          29    2017-01-20
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20

# %% [markdown]
# ### Sorting by multiple variables

# %%
dogs.sort_values(['Weight(kg)', 'Height(cm)'])
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 4      Max     Labrador  Black          59          29    2017-01-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Sorting by multiple variables [2]

# %%
dogs.sort_values(['Weight(kg)', 'Height(cm)'], ascending=[True, False])
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 4      Max     Labrador  Black          59          29    2017-01-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Subsetting columns

# %%
dogs['Name']
# Out:
# 0      Bella
# 1    Charlie
# 2       Lucy
# 3     Cooper
# 4        Max
# 5     Stella
# 6     Bernie
# Name: Name, dtype: object

# %% [markdown]
# ### Subsetting multiple columns

# %%
dogs[['Breed', 'Height(cm)']]
# Out:
#          Breed  Height(cm)
# 0     Labrador          56
# 1       Poodle          43
# 2    Chow Chow          46
# 3    Schnauzer          49
# 4     Labrador          59
# 5    Chihuahua          18
# 6  St. Bernard          77

# %% [markdown]
# #### Another subsetting approach

# %%
cols_to_subset = ['Breed', 'Height(cm)']
dogs[cols_to_subset]
# Out:
#          Breed  Height(cm)
# 0     Labrador          56
# 1       Poodle          43
# 2    Chow Chow          46
# 3    Schnauzer          49
# 4     Labrador          59
# 5    Chihuahua          18
# 6  St. Bernard          77

# %% [markdown]
# ### Subsetting rows

# %%
dogs['Height(cm)'] > 50
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Height(cm), dtype: bool

# %%
dogs[dogs['Height(cm)'] > 50]
# Out:
#      Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0   Bella     Labrador  Brown          56          25    2013-07-01
# 4     Max     Labrador  Black          59          29    2017-01-20
# 6  Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Subsetting based on text data

# %%
dogs[dogs['Breed'] == 'Labrador']
# Out:
#     Name     Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0  Bella  Labrador  Brown          56          25    2013-07-01
# 4    Max  Labrador  Black          59          29    2017-01-20

# %% [markdown]
# ### Subsetting based on dates

# %%
dogs[dogs['Date of Birth'] > '2015-01-01']
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 4      Max     Labrador  Black          59          29    2017-01-20
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Subsetting based on multiple conditions

# %%
is_lab = dogs['Breed'] == 'Labrador'
is_brown = dogs['Color'] == 'Brown'
dogs[is_lab & is_brown]
# Out:
#     Name     Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0  Bella  Labrador  Brown          56          25    2013-07-01

# %%
dogs[ (dogs['Breed'] == 'Labrador') & (dogs['Color'] == 'Brown') ]
# Out:
#     Name     Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0  Bella  Labrador  Brown          56          25    2013-07-01

# %% [markdown]
# ### Subsetting using `.isin()`
#
# Subsetting data based on a categorical variable often involves using the "or" operator (`|`) to select rows from multiple categories. This can get tedious when you want all states in one of three different regions, for example. Instead, use the `.isin()` method, which will allow you to tackle this problem by writing one condition instead of three separate ones.

# %%
is_black_or_brown = dogs['Color'].isin(['Black', 'Brown'])
dogs[is_black_or_brown]
# Out:
#       Name      Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella   Labrador  Brown          56          25    2013-07-01
# 1  Charlie     Poodle  Black          43          23    2016-09-16
# 2     Lucy  Chow Chow  Brown          46          22    2014-08-25
# 4      Max   Labrador  Black          59          29    2017-01-20

# %% [markdown]
# ## New columns

# %% [markdown]
# ### Adding a new columns

# %%
dogs['Height(m)'] = dogs['Height(cm)'] / 100
dogs
# Out:
#       Name        Breed  Color  ...  Date of Birth  Height(m)         bmi
# 0    Bella     Labrador  Brown  ...     2013-07-01       0.56   79.719388
# 1  Charlie       Poodle  Black  ...     2016-09-16       0.43  124.391563
# 2     Lucy    Chow Chow  Brown  ...     2014-08-25       0.46  103.969754
# 3   Cooper    Schnauzer   Gray  ...     2011-12-11       0.49   70.803832
# 4      Max     Labrador  Black  ...     2017-01-20       0.59   83.309394
# 5   Stella    Chihuahua    Tan  ...     2015-04-20       0.18   61.728395
# 6   Bernie  St. Bernard  White  ...     2018-02-27       0.77  124.810255
#
# [7 rows x 8 columns]

# %% [markdown]
# ### Doggy mass index
#
# BMI = weight in kg / (height in m)²

# %%
dogs['bmi'] = dogs['Weight(kg)'] / dogs['Height(m)'] ** 2
dogs.head()
# Out:
#       Name      Breed  Color  ...  Date of Birth  Height(m)         bmi
# 0    Bella   Labrador  Brown  ...     2013-07-01       0.56   79.719388
# 1  Charlie     Poodle  Black  ...     2016-09-16       0.43  124.391563
# 2     Lucy  Chow Chow  Brown  ...     2014-08-25       0.46  103.969754
# 3   Cooper  Schnauzer   Gray  ...     2011-12-11       0.49   70.803832
# 4      Max   Labrador  Black  ...     2017-01-20       0.59   83.309394
#
# [5 rows x 8 columns]

# %% [markdown]
# ### Multiple manipulations

# %%
bmi_lt_100 = dogs[dogs['bmi'] < 100]
bmi_lt_100_height = bmi_lt_100.sort_values('Height(cm)', ascending=False)
bmi_lt_100_height[['Name', 'Height(cm)', 'bmi']]
# Out:
#      Name  Height(cm)        bmi
# 4     Max          59  83.309394
# 0   Bella          56  79.719388
# 3  Cooper          49  70.803832
# 5  Stella          18  61.728395

# %% [markdown]
# # Chapter 2 - Aggregating Data
#
# In this chapter, you’ll calculate summary statistics on DataFrame columns, and master grouped summary statistics and pivot tables.

# %% [markdown]
# ## Summary statistics

# %% [markdown]
# ### Summarizing numerical data
#
# * Some options: .median() , .mode(), .min(), .max(), .var(), .std(), .sum(), .quantile()

# %%
dogs['Height(cm)'].mean()
# Out:
# 49.714285714285715

# %%
dogs['Weight(kg)'].max()
# Out:
# 74

# %%
dogs['bmi'].sum()
# Out:
# 648.7325803466715

# %% [markdown]
# ### Summarizing dates

# %%
# Oldest dog
dogs['Date of Birth'].min()
# Out:
# Timestamp('2011-12-11 00:00:00')

# %%
# Youngest dog
dogs['Date of Birth'].max()
# Out:
# Timestamp('2018-02-27 00:00:00')

# %% [markdown]
# ### The `.agg()` method
#
# While pandas and NumPy have tons of functions, sometimes you may need a different function to summarize your data. The `.agg()` method allows you to apply your own custom functions to a DataFrame, as well as apply functions to more than one column of a DataFrame at once, making your **aggregations** super efficient.

# %%
def pct30(column):
    return column.quantile(0.3)

dogs['Weight(kg)'].agg(pct30)
# Out:
# 20.999999999999996

# %% [markdown]
# ### Summaries on multiple columns

# %%
dogs[['Weight(kg)', 'Height(cm)']].agg(pct30)
# Out:
# Weight(kg)    21.0
# Height(cm)    45.4
# dtype: float64

# %% [markdown]
# ### Multiple summaries

# %%
def pct40(column):
    return column.quantile(0.4)

dogs['Weight(kg)'].agg([pct30, pct40])
# Out:
# pct30    21.0
# pct40    22.4
# Name: Weight(kg), dtype: float64

# %% [markdown]
# ### Cumulative sum

# %%
dogs['Weight(kg)']
# Out:
# 0    25
# 1    23
# 2    22
# 3    17
# 4    29
# 5     2
# 6    74
# Name: Weight(kg), dtype: int64

# %%
dogs['Weight(kg)'].cumsum()
# Out:
# 0     25
# 1     48
# 2     70
# 3     87
# 4    116
# 5    118
# 6    192
# Name: Weight(kg), dtype: int64

# %% [markdown]
# ### Cumulative statistics
#
# * `.cummax()`
# * `.cummin()`
# * `.cumprod()`

# %% [markdown]
# ## Counting

# %%
import pandas as pd

filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/walmart_sales.pkl'
sales = pd.read_pickle(filepath)

sales
# Out:
#         store type  ...  fuel_price_usd_per_l unemployment
# 0           1    A  ...              0.679451        8.106
# 1           1    A  ...              0.679451        8.106
# 2           1    A  ...              0.679451        8.106
# 3           1    A  ...              0.679451        8.106
# 4           1    A  ...              0.679451        8.106
# ...       ...  ...  ...                   ...          ...
# 413114     45    B  ...              1.025516        8.667
# 413115     45    B  ...              1.025516        8.667
# 413116     45    B  ...              1.025516        8.667
# 413117     45    B  ...              1.025516        8.667
# 413118     45    B  ...              1.025516        8.667
#
# [413119 rows x 9 columns]

# %%
sales.info() # more than #400k rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 413119 entries, 0 to 413118
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   store                 413119 non-null  int64
#  1   type                  413119 non-null  object
#  2   department            413119 non-null  int32
#  3   date                  413119 non-null  datetime64[ns]
#  4   weekly_sales          413119 non-null  float64
#  5   is_holiday            413119 non-null  bool
#  6   temperature_c         413119 non-null  float64
#  7   fuel_price_usd_per_l  413119 non-null  float64
#  8   unemployment          413119 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(4), int32(1), int64(1), object(1)
# memory usage: 27.2+ MB

# %% [markdown]
# ### Dropping duplicate departments

# %%
sales.drop_duplicates(subset='department')
# Out:
#         store type  ...  fuel_price_usd_per_l unemployment
# 0           1    A  ...              0.679451        8.106
# 1           1    A  ...              0.679451        8.106
# 2           1    A  ...              0.679451        8.106
# 3           1    A  ...              0.679451        8.106
# 4           1    A  ...              0.679451        8.106
# ...       ...  ...  ...                   ...          ...
# 6786        1    A  ...              0.854861        7.866
# 10426       2    A  ...              0.664129        8.324
# 87569      10    B  ...              0.782478        9.765
# 124611     13    A  ...              0.895280        6.392
# 320587     34    A  ...              0.686319        9.521
#
# [81 rows x 9 columns]

# %% [markdown]
# ### Dropping duplicate pairs

# %%
unique_departments = sales.drop_duplicates(subset=['department', 'type'])
unique_departments
# Out:
#         store type  ...  fuel_price_usd_per_l unemployment
# 0           1    A  ...              0.679451        8.106
# 1           1    A  ...              0.679451        8.106
# 2           1    A  ...              0.679451        8.106
# 3           1    A  ...              0.679451        8.106
# 4           1    A  ...              0.679451        8.106
# ...       ...  ...  ...                   ...          ...
# 289586     30    C  ...              0.956832        7.931
# 291874     30    C  ...              0.927244        7.057
# 320587     34    A  ...              0.686319        9.521
# 348760     37    C  ...              0.762401        8.476
# 355483     38    C  ...              0.795951       14.313
#
# [227 rows x 9 columns]

# %% [markdown]
# ### Count values with `.value_counts()`

# %%
unique_departments['store'].value_counts()
# Out:
# 1     77
# 3     72
# 30    64
# 7      3
# 10     2
# 38     1
# 37     1
# 34     1
# 18     1
# 15     1
# 13     1
# 11     1
# 5      1
# 2      1
# Name: store, dtype: int64

# %%
unique_departments['store'].value_counts(sort=True)
# Out:
# 1     77
# 3     72
# 30    64
# 7      3
# 10     2
# 38     1
# 37     1
# 34     1
# 18     1
# 15     1
# 13     1
# 11     1
# 5      1
# 2      1
# Name: store, dtype: int64

# %% [markdown]
# ### Proportions

# %%
unique_departments['store'].value_counts(normalize=True)
# Out:
# 1     0.339207
# 3     0.317181
# 30    0.281938
# 7     0.013216
# 10    0.008811
# 38    0.004405
# 37    0.004405
# 34    0.004405
# 18    0.004405
# 15    0.004405
# 13    0.004405
# 11    0.004405
# 5     0.004405
# 2     0.004405
# Name: store, dtype: float64

# %% [markdown]
# ## Grouped summary statistics

# %%
import pandas as pd

filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/dogs.xlsx'
dogs = pd.read_excel(filepath)
dogs
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 4      Max     Labrador  Black          59          29    2017-01-20
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Summaries by group

# %%
print(dogs[dogs['Color'] == 'Black']['Weight(kg)'].mean())
print(dogs[dogs['Color'] == "Brown"]['Weight(kg)'].mean())
print(dogs[dogs['Color'] == 'White']['Weight(kg)'].mean())
# Out:
# 26.0
# 23.5
# 74.0

# %% [markdown]
# ### Grouped summaries

# %%
dogs.groupby('Color')['Weight(kg)'].mean()
# Out:
# Color
# Black    26.0
# Brown    23.5
# Gray     17.0
# Tan       2.0
# White    74.0
# Name: Weight(kg), dtype: float64

# %% [markdown]
# ### Multiple grouped summaries
#
# Earlier in this chapter you saw that the `.agg()` method is useful to compute multiple statistics on multiple variables. It also works with grouped data.
#
# NumPy, which is imported as `np`, has many different summary statistics functions, including: `np.min`, `np.max`, `np.mean`, and `np.median`.

# %%
import numpy as np
dogs.groupby('Color')['Weight(kg)'].agg([np.min, np.max, np.sum])
# Out:
#        amin  amax  sum
# Color
# Black    23    29   52
# Brown    22    25   47
# Gray     17    17   17
# Tan       2     2    2
# White    74    74   74

# %% [markdown]
# ### Grouping by multiple variables

# %%
dogs.groupby(['Color', 'Breed'])['Weight(kg)'].mean()
# Out:
# Color  Breed
# Black  Labrador       29
#        Poodle         23
# Brown  Chow Chow      22
#        Labrador       25
# Gray   Schnauzer      17
# Tan    Chihuahua       2
# White  St. Bernard    74
# Name: Weight(kg), dtype: int64

# %% [markdown]
# ### Many groups, many summaries

# %%
dogs.groupby(['Color', 'Breed'])[['Weight(kg)', 'Height(cm)']].mean()
# Out:
#                    Weight(kg)  Height(cm)
# Color Breed
# Black Labrador             29          59
#       Poodle               23          43
# Brown Chow Chow            22          46
#       Labrador             25          56
# Gray  Schnauzer            17          49
# Tan   Chihuahua             2          18
# White St. Bernard          74          77

# %% [markdown]
# ## Pivot tables
#
# Pivot tables are the standard way of aggregating data in spreadsheets. In pandas, pivot tables are essentially just another way of performing grouped calculations. That is, the `.pivot_table()` method is just an alternative to `.groupby()`.

# %% [markdown]
# ### Group by to pivot table

# %%
dogs.groupby('Color')['Weight(kg)'].mean()
# Out:
# Color
# Black    26.0
# Brown    23.5
# Gray     17.0
# Tan       2.0
# White    74.0
# Name: Weight(kg), dtype: float64

# %%
dogs.pivot_table(values='Weight(kg)', index='Color')
# Out:
#        Weight(kg)
# Color
# Black        26.0
# Brown        23.5
# Gray         17.0
# Tan           2.0
# White        74.0

# %% [markdown]
# ### Different statistics

# %%
import numpy as np
dogs.pivot_table(values='Weight(kg)', index='Color', aggfunc=np.median)
# Out:
#        Weight(kg)
# Color
# Black        26.0
# Brown        23.5
# Gray         17.0
# Tan           2.0
# White        74.0

# %% [markdown]
# ### Multiple statistics

# %%
dogs.pivot_table(values='Weight(kg)', index='Color', aggfunc=[np.mean, np.median])
# Out:
#             mean     median
#       Weight(kg) Weight(kg)
# Color
# Black       26.0       26.0
# Brown       23.5       23.5
# Gray        17.0       17.0
# Tan          2.0        2.0
# White       74.0       74.0

# %% [markdown]
# ### Pivot on two variables

# %%
dogs.groupby(['Color', 'Breed'])['Weight(kg)'].mean()
# Out:
# Color  Breed
# Black  Labrador       29
#        Poodle         23
# Brown  Chow Chow      22
#        Labrador       25
# Gray   Schnauzer      17
# Tan    Chihuahua       2
# White  St. Bernard    74
# Name: Weight(kg), dtype: int64

# %%
dogs.pivot_table(values='Weight(kg)', index='Color', columns='Breed')
# Out:
# Breed  Chihuahua  Chow Chow  Labrador  Poodle  Schnauzer  St. Bernard
# Color
# Black        NaN        NaN      29.0    23.0        NaN          NaN
# Brown        NaN       22.0      25.0     NaN        NaN          NaN
# Gray         NaN        NaN       NaN     NaN       17.0          NaN
# Tan          2.0        NaN       NaN     NaN        NaN          NaN
# White        NaN        NaN       NaN     NaN        NaN         74.0

# %% [markdown]
# ### Filling missing values in pivot tables

# %%
dogs.pivot_table(values='Weight(kg)', index='Color', columns='Breed', fill_value=0)
# Out:
# Breed  Chihuahua  Chow Chow  Labrador  Poodle  Schnauzer  St. Bernard
# Color
# Black          0          0        29      23          0            0
# Brown          0         22        25       0          0            0
# Gray           0          0         0       0         17            0
# Tan            2          0         0       0          0            0
# White          0          0         0       0          0           74

# %% [markdown]
# ### Summing with pivot tables

# %%
dogs.pivot_table(values='Weight(kg)', index='Color', columns='Breed', fill_value=0, margins=True)
# Out:
# Breed  Chihuahua  Chow Chow  Labrador  Poodle  Schnauzer  St. Bernard   All
# Color
# Black          0          0        29      23          0            0  26.0
# Brown          0         22        25       0          0            0  23.5
# Gray           0          0         0       0         17            0  17.0
# Tan            2          0         0       0          0            0   2.0
# White          0          0         0       0          0           74  74.0
# All            2         22        27      23         17           74  27.0

# %% [markdown]
# # Chapter 3 - Slicing and indexing
#
# Indexes are supercharged row and column names. Learn how they can be combined with slicing for powerful DataFrame subsetting.

# %%
import pandas as pd
filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/dogs.xlsx'
dogs = pd.read_excel(filepath)
dogs
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 4      Max     Labrador  Black          59          29    2017-01-20
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ## Explicit indexes

# %% [markdown]
# ### `.columns` and `.index`

# %%
dogs.columns
# Out:
# Index(['Name', 'Breed', 'Color', 'Height(cm)', 'Weight(kg)', 'Date of Birth'], dtype='object')

# %%
dogs.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# ### Setting a column as the index

# %%
dogs_ind = dogs.set_index('Name')
print(dogs_ind)
# Out:
#                Breed  Color  Height(cm)  Weight(kg) Date of Birth
# Name
# Bella       Labrador  Brown          56          25    2013-07-01
# Charlie       Poodle  Black          43          23    2016-09-16
# Lucy       Chow Chow  Brown          46          22    2014-08-25
# Cooper     Schnauzer   Gray          49          17    2011-12-11
# Max         Labrador  Black          59          29    2017-01-20
# Stella     Chihuahua    Tan          18           2    2015-04-20
# Bernie   St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Removing an index

# %%
dogs_ind.reset_index()
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 4      Max     Labrador  Black          59          29    2017-01-20
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Dropping an index

# %%
dogs_ind.reset_index(drop=True) # Drop current index, which is 'Name' in dogs_ind
# Out:
#          Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0     Labrador  Brown          56          25    2013-07-01
# 1       Poodle  Black          43          23    2016-09-16
# 2    Chow Chow  Brown          46          22    2014-08-25
# 3    Schnauzer   Gray          49          17    2011-12-11
# 4     Labrador  Black          59          29    2017-01-20
# 5    Chihuahua    Tan          18           2    2015-04-20
# 6  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Indexes make subsetting simpler

# %%
dogs[dogs['Name'].isin(['Bella', 'Stella'])]
# Out:
#      Name      Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0   Bella   Labrador  Brown          56          25    2013-07-01
# 5  Stella  Chihuahua    Tan          18           2    2015-04-20

# %%
dogs_ind.loc[['Bella', 'Stella']]
# Out:
#             Breed  Color  Height(cm)  Weight(kg) Date of Birth
# Name
# Bella    Labrador  Brown          56          25    2013-07-01
# Stella  Chihuahua    Tan          18           2    2015-04-20

# %% [markdown]
# ### Index values don't need to be unique

# %%
dogs_ind2 = dogs.set_index('Breed')
print(dogs_ind2)
# Out:
#                 Name  Color  Height(cm)  Weight(kg) Date of Birth
# Breed
# Labrador       Bella  Brown          56          25    2013-07-01
# Poodle       Charlie  Black          43          23    2016-09-16
# Chow Chow       Lucy  Brown          46          22    2014-08-25
# Schnauzer     Cooper   Gray          49          17    2011-12-11
# Labrador         Max  Black          59          29    2017-01-20
# Chihuahua     Stella    Tan          18           2    2015-04-20
# St. Bernard   Bernie  White          77          74    2018-02-27

# %% [markdown]
# ### Subsetting on duplicated index values

# %%
dogs_ind2.loc['Labrador']
# Out:
#            Name  Color  Height(cm)  Weight(kg) Date of Birth
# Breed
# Labrador  Bella  Brown          56          25    2013-07-01
# Labrador    Max  Black          59          29    2017-01-20

# %% [markdown]
# ### Multi-level indexes a.k.a. hierarchical indexes

# %%
dogs_ind3 = dogs.set_index(['Breed', 'Color'])
print(dogs_ind3)
# Out:
#                       Name  Height(cm)  Weight(kg) Date of Birth
# Breed       Color
# Labrador    Brown    Bella          56          25    2013-07-01
# Poodle      Black  Charlie          43          23    2016-09-16
# Chow Chow   Brown     Lucy          46          22    2014-08-25
# Schnauzer   Gray    Cooper          49          17    2011-12-11
# Labrador    Black      Max          59          29    2017-01-20
# Chihuahua   Tan     Stella          18           2    2015-04-20
# St. Bernard White   Bernie          77          74    2018-02-27

# %% [markdown]
# ### Subset the outer level with a list

# %%
dogs_ind3.loc[['Labrador', 'Chihuahua']]
# Out:
#                    Name  Height(cm)  Weight(kg) Date of Birth
# Breed     Color
# Labrador  Brown   Bella          56          25    2013-07-01
#           Black     Max          59          29    2017-01-20
# Chihuahua Tan    Stella          18           2    2015-04-20

# %% [markdown]
# ### Subset inner levels with a list oftuples

# %%
dogs_ind3.loc[[('Labrador', 'Brown'), ('Chihuahua', 'Tan')]]
# Out:
#                    Name  Height(cm)  Weight(kg) Date of Birth
# Breed     Color
# Labrador  Brown   Bella          56          25    2013-07-01
# Chihuahua Tan    Stella          18           2    2015-04-20

# %% [markdown]
# ### Sorting by index values

# %%
dogs_ind3.sort_index()
# Out:
#                       Name  Height(cm)  Weight(kg) Date of Birth
# Breed       Color
# Chihuahua   Tan     Stella          18           2    2015-04-20
# Chow Chow   Brown     Lucy          46          22    2014-08-25
# Labrador    Black      Max          59          29    2017-01-20
#             Brown    Bella          56          25    2013-07-01
# Poodle      Black  Charlie          43          23    2016-09-16
# Schnauzer   Gray    Cooper          49          17    2011-12-11
# St. Bernard White   Bernie          77          74    2018-02-27

# %% [markdown]
# ### Controlling `sort_index()`

# %%
dogs_ind3.sort_index(level=['Color', 'Breed'], ascending=[True, False])
# Out:
#                       Name  Height(cm)  Weight(kg) Date of Birth
# Breed       Color
# Poodle      Black  Charlie          43          23    2016-09-16
# Labrador    Black      Max          59          29    2017-01-20
#             Brown    Bella          56          25    2013-07-01
# Chow Chow   Brown     Lucy          46          22    2014-08-25
# Schnauzer   Gray    Cooper          49          17    2011-12-11
# Chihuahua   Tan     Stella          18           2    2015-04-20
# St. Bernard White   Bernie          77          74    2018-02-27

# %% [markdown]
# ### Problems with indexes
#
# * Indexes are controversial. Although they simplify subsetting code, there are some downsides.
# * Index values are just data. Storing data in multiple forms makes it harder to think about.
# * There is a concept called "tidy data", where data is stored in tabular form, like a DataFrame. Each row contains a single observation, and each variable is stored in its own column.
# * Indexes violate the last rule, since index values don't get their own column.
# * In pandas, the syntex for working with indexes is different from the syntex for working with columns.
#   * By using two syntaxes, your code is more complicated, which can result in more bugs.
# * If you decide not to use indexes, that's perfectly reasonable. However, it's useful to know how they work for cases when you need to read other people's code.

# %% [markdown]
# ## Slicing and subsetting with `.loc` and `.iloc`
#
# Slicing lets you select consecutive elements of an object using `first:last` syntax. DataFrames can be sliced by index values, or by row/column number. This involves slicing inside the `.loc[]` method.
# <br><br>
# Compared to slicing lists, there are a few things to remember.
# * You can only slice an index if the index is sorted (using `.sort_index()`).
# * To slice at the outer level, `first` and `last` can be strings.
# * To slice at inner levels, `first` and `last` should be tuples.
# * If you pass a single slice to `.loc[]`, it will slice the rows.

# %% [markdown]
# ### Slicing lists

# %%
breeds = ['Labrador', 'Poodle', 'Chow Chow', 'Schnauzer', 'Labrador', 'Chihuahua', 'St. Bernard']

# %%
breeds[2:5]
# Out:
# ['Chow Chow', 'Schnauzer', 'Labrador']

# %%
breeds[:3]
# Out:
# ['Labrador', 'Poodle', 'Chow Chow']

# %%
breeds[:]
# Out:
# ['Labrador',
#  'Poodle',
#  'Chow Chow',
#  'Schnauzer',
#  'Labrador',
#  'Chihuahua',
#  'St. Bernard']

# %%
breeds[:-1]
# Out:
# ['Labrador', 'Poodle', 'Chow Chow', 'Schnauzer', 'Labrador', 'Chihuahua']

# %% [markdown]
# ### Sortthe index before you slice

# %%
dogs_srt = dogs.set_index(['Breed', 'Color']).sort_index()
print(dogs_srt)
# Out:
#                       Name  Height(cm)  Weight(kg) Date of Birth
# Breed       Color
# Chihuahua   Tan     Stella          18           2    2015-04-20
# Chow Chow   Brown     Lucy          46          22    2014-08-25
# Labrador    Black      Max          59          29    2017-01-20
#             Brown    Bella          56          25    2013-07-01
# Poodle      Black  Charlie          43          23    2016-09-16
# Schnauzer   Gray    Cooper          49          17    2011-12-11
# St. Bernard White   Bernie          77          74    2018-02-27

# %% [markdown]
# ### Slicing the outer index level

# %%
dogs_srt.loc['Chow Chow':'Poodle'] # Final value "Poodle" is included
# Out:
#                     Name  Height(cm)  Weight(kg) Date of Birth
# Breed     Color
# Chow Chow Brown     Lucy          46          22    2014-08-25
# Labrador  Black      Max          59          29    2017-01-20
#           Brown    Bella          56          25    2013-07-01
# Poodle    Black  Charlie          43          23    2016-09-16

# %% [markdown]
# ### Slicing the inner index levels badly

# %%
dogs_srt.loc['Tan':'Grey']
# Out:
# Empty DataFrame
# Columns: [Name, Height(cm), Weight(kg), Date of Birth]
# Index: []

# %% [markdown]
# ### Slicing the inner index levels correctly

# %%
dogs_srt.loc[('Labrador','Brown'):('Schnauzer','Grey')]
# Out:
#                     Name  Height(cm)  Weight(kg) Date of Birth
# Breed     Color
# Labrador  Brown    Bella          56          25    2013-07-01
# Poodle    Black  Charlie          43          23    2016-09-16
# Schnauzer Gray    Cooper          49          17    2011-12-11

# %% [markdown]
# ### Slicing columns

# %%
dogs_srt.loc[:,'Name':'Height(cm)']
# Out:
#                       Name  Height(cm)
# Breed       Color
# Chihuahua   Tan     Stella          18
# Chow Chow   Brown     Lucy          46
# Labrador    Black      Max          59
#             Brown    Bella          56
# Poodle      Black  Charlie          43
# Schnauzer   Gray    Cooper          49
# St. Bernard White   Bernie          77

# %% [markdown]
# ### Slice twice
#
# You've seen slicing DataFrames by rows and by columns, but since DataFrames are two dimensional objects it is often natural to slice both dimensions at once. That is, by passing two arguments to `.loc[]`, you can subset by rows and columns in one go.

# %%
dogs_srt.loc[('Labrador','Brown'):('Schnauzer','Grey'),'Name':'Height(cm)']
# Out:
#                     Name  Height(cm)
# Breed     Color
# Labrador  Brown    Bella          56
# Poodle    Black  Charlie          43
# Schnauzer Gray    Cooper          49

# %% [markdown]
# ### Dog days

# %%
dogs = dogs.set_index('Date of Birth').sort_index()
print(dogs)
# Out:
#                   Name        Breed  Color  Height(cm)  Weight(kg)
# Date of Birth
# 2011-12-11      Cooper    Schnauzer   Gray          49          17
# 2013-07-01       Bella     Labrador  Brown          56          25
# 2014-08-25        Lucy    Chow Chow  Brown          46          22
# 2015-04-20      Stella    Chihuahua    Tan          18           2
# 2016-09-16     Charlie       Poodle  Black          43          23
# 2017-01-20         Max     Labrador  Black          59          29
# 2018-02-27      Bernie  St. Bernard  White          77          74

# %% [markdown]
# ### Slicing by dates
#
# Slicing is particularly useful for time series, since it's a common thing to want to filter for data within a date range. Add the `date` column to the index, then use `.loc[]` to perform the subsetting. The important thing to remember is to keep your dates in ISO 8601 format, that is, `yyyy-mm-dd`.

# %%
# Get dogs with date_of_birth between 2014-08-25 and 2016-09-16
dogs.loc['2014-08-25':'2016-09-16']
# Out:
#                   Name      Breed  Color  Height(cm)  Weight(kg)
# Date of Birth
# 2014-08-25        Lucy  Chow Chow  Brown          46          22
# 2015-04-20      Stella  Chihuahua    Tan          18           2
# 2016-09-16     Charlie     Poodle  Black          43          23

# %% [markdown]
# ### Slicing by partial dates

# %%
# Get dogs with date_of_birth between 2014-01-01 and 2016-12-31
dogs.loc['2014':'2016']
# Out:
#                   Name      Breed  Color  Height(cm)  Weight(kg)
# Date of Birth
# 2014-08-25        Lucy  Chow Chow  Brown          46          22
# 2015-04-20      Stella  Chihuahua    Tan          18           2
# 2016-09-16     Charlie     Poodle  Black          43          23

# %% [markdown]
# ### Subsetting by row/column number
#
# The most common ways to subset rows are the ways we've previously discussed: using a Boolean condition, or by index labels. However, it is also occasionally useful to pass row numbers.
#
# This is done using `.iloc[]`, and like `.loc[]`, it can take two arguments to let you subset by rows and columns.

# %%
print(dogs.iloc[2:5, 1:4])
# Out:
#                    Breed  Color  Height(cm)
# Date of Birth
# 2014-08-25     Chow Chow  Brown          46
# 2015-04-20     Chihuahua    Tan          18
# 2016-09-16        Poodle  Black          43

# %% [markdown]
# ## Working with pivot tables

# %% [markdown]
# ### Pivoting the dogs

# %%
dogs_height_by_breed_vs_color = dogs.pivot_table('Height(cm)', index='Breed', columns='Color')
print(dogs_height_by_breed_vs_color)
# Out:
# Color        Black  Brown  Gray   Tan  White
# Breed
# Chihuahua      NaN    NaN   NaN  18.0    NaN
# Chow Chow      NaN   46.0   NaN   NaN    NaN
# Labrador      59.0   56.0   NaN   NaN    NaN
# Poodle        43.0    NaN   NaN   NaN    NaN
# Schnauzer      NaN    NaN  49.0   NaN    NaN
# St. Bernard    NaN    NaN   NaN   NaN   77.0

# %% [markdown]
# ### `.loc[]` + slicing is a power combo

# %%
dogs_height_by_breed_vs_color.loc['Chow Chow':'Poodle']
# Out:
# Color      Black  Brown  Gray  Tan  White
# Breed
# Chow Chow    NaN   46.0   NaN  NaN    NaN
# Labrador    59.0   56.0   NaN  NaN    NaN
# Poodle      43.0    NaN   NaN  NaN    NaN

# %% [markdown]
# ### The axis argument

# %%
dogs_height_by_breed_vs_color.mean(axis='index')
# Out:
# Color
# Black    51.0
# Brown    51.0
# Gray     49.0
# Tan      18.0
# White    77.0
# dtype: float64

# %% [markdown]
# ### Calculating summary stats across columns

# %%
dogs_height_by_breed_vs_color.mean(axis='columns')
# Out:
# Breed
# Chihuahua      18.0
# Chow Chow      46.0
# Labrador       57.5
# Poodle         43.0
# Schnauzer      49.0
# St. Bernard    77.0
# dtype: float64

# %% [markdown]
# # Chapter 4 - Creating and Visualizing DataFrames
#
# Learn to visualize the contents of your DataFrames, handle missing data values, and import data from and export data to CSV files.

# %% [markdown]
# ## Visualizing your data

# %%
import pandas as pd
filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/dogs.xlsx'
dogs = pd.read_excel(filepath)
dogs
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56          25    2013-07-01
# 1  Charlie       Poodle  Black          43          23    2016-09-16
# 2     Lucy    Chow Chow  Brown          46          22    2014-08-25
# 3   Cooper    Schnauzer   Gray          49          17    2011-12-11
# 4      Max     Labrador  Black          59          29    2017-01-20
# 5   Stella    Chihuahua    Tan          18           2    2015-04-20
# 6   Bernie  St. Bernard  White          77          74    2018-02-27

# %% [markdown]
# ### Histograms

# %%
import matplotlib.pyplot as plt

dogs['Height(cm)'].hist()
plt.show()

# %%
dogs['Height(cm)'].hist(bins=20)
plt.show()

# %%
dogs['Height(cm)'].hist(bins=5)
plt.show()

# %% [markdown]
# ### Bar plots

# %%
avg_weight_by_breed = dogs.groupby('Breed')['Weight(kg)'].mean()
print(avg_weight_by_breed)
# Out:
# Breed
# Chihuahua       2
# Chow Chow      22
# Labrador       27
# Poodle         23
# Schnauzer      17
# St. Bernard    74
# Name: Weight(kg), dtype: int64

# %%
avg_weight_by_breed.plot(kind="bar",title="Mean Weight by Dog Breed")
plt.show()

# %% [markdown]
# ### Line plots

# %%
dogs.plot(x='Date of Birth', y='Weight(kg)', kind='line')
plt.show()

# %% [markdown]
# ### Rotating axis labels

# %%
dogs.plot(x='Date of Birth', y='Weight(kg)', kind='line', rot=90)
plt.show()

# %% [markdown]
# ### Scatter plots

# %%
dogs.plot(x='Height(cm)', y='Weight(kg)', kind='scatter')
plt.show()

# %% [markdown]
# ### Layering plots

# %%
dogs[dogs['Color']=='Black']['Height(cm)'].hist()
dogs[dogs['Color']=='Brown']['Height(cm)'].hist()
plt.show()

# %% [markdown]
# ### Add legend

# %%
dogs[dogs['Color']=='Black']['Height(cm)'].hist()
dogs[dogs['Color']=='Brown']['Height(cm)'].hist()
plt.legend(['Black', 'Brown'])
plt.show()

# %% [markdown]
# ### Transparency

# %%
dogs[dogs['Color']=='Black']['Height(cm)'].hist(alpha=0.7)
dogs[dogs['Color']=='Brown']['Height(cm)'].hist(alpha=0.7)
plt.legend(['Black', 'Brown'])
plt.show()

# %% [markdown]
# ### Exercise - Avocados

# %%
import pandas as pd

filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/avoplotto.pkl'
avocados = pd.read_pickle(filepath)
avocados
# Out:
#             date          type  year  avg_price         size     nb_sold
# 0     2015-12-27  conventional  2015       0.95        small  9626901.09
# 1     2015-12-20  conventional  2015       0.98        small  8710021.76
# 2     2015-12-13  conventional  2015       0.93        small  9855053.66
# 3     2015-12-06  conventional  2015       0.89        small  9405464.36
# 4     2015-11-29  conventional  2015       0.99        small  8094803.56
# ...          ...           ...   ...        ...          ...         ...
# 1009  2018-02-04       organic  2018       1.53  extra_large     1703.52
# 1010  2018-01-28       organic  2018       1.61  extra_large     1270.61
# 1011  2018-01-21       organic  2018       1.63  extra_large     1490.02
# 1012  2018-01-14       organic  2018       1.59  extra_large     1580.01
# 1013  2018-01-07       organic  2018       1.51  extra_large     1289.07
#
# [1014 rows x 6 columns]

# %% [markdown]
# #### Which avocado size is most popular?

# %%
import matplotlib.pyplot as plt

# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby("size")["nb_sold"].sum()

# Create a bar plot of the number of avocados sold by size
nb_sold_by_size.plot(kind="bar")
plt.show()

# %% [markdown]
# #### Changes in sales over time

# %%
import matplotlib.pyplot as plt

# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")["nb_sold"].sum()

# Create a line plot of the number of avocados sold by date
nb_sold_by_date.plot(kind="line", rot=45)
plt.show()

# %% [markdown]
# #### Avocado supply and demand

# %%
# Scatter plot of nb_sold vs avg_price with title
avocados.plot(x="nb_sold", y="avg_price", kind="scatter", 
              title="Number of avocados sold vs. average price")
plt.show()

# %% [markdown]
# #### Price of conventional vs. organic avocados

# %%
# Histogram of conventional avg_price 
avocados[avocados["type"]=="conventional"]["avg_price"].hist()

# Histogram of organic avg_price
avocados[avocados["type"]=="organic"]["avg_price"].hist()

# Add a legend
plt.legend(["conventional", "organic"])
plt.show()

# %% [markdown]
# ## Missing values
#
# A missing value is a value that is absent in the DataFrame. A cell in a DataFrame with no information has a missing value.
#
# Missing values are everywhere, and you don't want them interfering with your work. Some functions ignore missing data by default, but that's not always the behavior you might want. Some functions can't handle missing values at all, so these values need to be taken care of before you can use them. If you don't know where your missing values are, or if they exist, you could make mistakes in your analysis. In this exercise, you'll determine if there are missing values in the dataset, and if so, how many.

# %%
import pandas as pd

filepath = '/content/drive/My Drive/Colab Notebooks/Career Track - Data Scientist with Python/04 - Course - Data Manipulation with pandas/datasets/dogs-na.xlsx'
dogs_na = pd.read_excel(filepath)
dogs_na
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56         NaN    2013-07-01
# 1  Charlie       Poodle  Black          43        23.0    2016-09-16
# 2     Lucy    Chow Chow  Brown          46        22.0    2014-08-25
# 3   Cooper    Schnauzer   Gray          49         NaN    2011-12-11
# 4      Max     Labrador  Black          59        29.0    2017-01-20
# 5   Stella    Chihuahua    Tan          18         2.0    2015-04-20
# 6   Bernie  St. Bernard  White          77        74.0    2018-02-27

# %% [markdown]
# ### Detecting missing values

# %%
dogs_na.isna()
# Out:
#     Name  Breed  Color  Height(cm)  Weight(kg)  Date of Birth
# 0  False  False  False       False        True          False
# 1  False  False  False       False       False          False
# 2  False  False  False       False       False          False
# 3  False  False  False       False        True          False
# 4  False  False  False       False       False          False
# 5  False  False  False       False       False          False
# 6  False  False  False       False       False          False

# %% [markdown]
# ### Detecting any missing values

# %%
dogs.isna().any()
# Out:
# Name             False
# Breed            False
# Color            False
# Height(cm)       False
# Weight(kg)       False
# Date of Birth    False
# dtype: bool

# %% [markdown]
# ### Counting missing values

# %%
dogs.isna().sum()
# Out:
# Name             0
# Breed            0
# Color            0
# Height(cm)       0
# Weight(kg)       0
# Date of Birth    0
# dtype: int64

# %% [markdown]
# ### Plotting missing values

# %%
import matplotlib.pyplot as plt

dogs_na.isna().sum().plot(kind="bar")
plt.show()

# %% [markdown]
# ### Removing missing values

# %%
dogs_na.dropna()
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 1  Charlie       Poodle  Black          43        23.0    2016-09-16
# 2     Lucy    Chow Chow  Brown          46        22.0    2014-08-25
# 4      Max     Labrador  Black          59        29.0    2017-01-20
# 5   Stella    Chihuahua    Tan          18         2.0    2015-04-20
# 6   Bernie  St. Bernard  White          77        74.0    2018-02-27

# %% [markdown]
# ### Replacing missing values

# %%
dogs_na.fillna(0)
# Out:
#       Name        Breed  Color  Height(cm)  Weight(kg) Date of Birth
# 0    Bella     Labrador  Brown          56         0.0    2013-07-01
# 1  Charlie       Poodle  Black          43        23.0    2016-09-16
# 2     Lucy    Chow Chow  Brown          46        22.0    2014-08-25
# 3   Cooper    Schnauzer   Gray          49         0.0    2011-12-11
# 4      Max     Labrador  Black          59        29.0    2017-01-20
# 5   Stella    Chihuahua    Tan          18         2.0    2015-04-20
# 6   Bernie  St. Bernard  White          77        74.0    2018-02-27

# %% [markdown]
# ## Creating DataFrames

# %% [markdown]
# ### Dictionaries

# %%
my_dict = {
    'key1': 10,
    'key2': 20,
    'key3': 30
    }
my_dict['key1']
# Out:
# 10

# %%
my_dict = {
    'title': 'Charlotte's Web',
    'author': 'E.B. White',
    'published': 1952
    }
my_dict['title']
# Out:
# "Charlotte's Web"

# %% [markdown]
# ### Creating DataFrames
#
# * From a list of dictionaries
#   * Constructed row by row
# * From a dictionary of lists
#   * Constructed column by column

# %% [markdown]
# ### List of dictionaries - by row

# %%
import pandas as pd
list_of_dicts = [ {'name': 'Ginger' , 'breed': 'Dachshund' , 'height_cm': 22, 
                        'weight_kg': 10, 'date_of_birth': '2019-03-14'}, 
                 {'name': 'Scout' , 'breed': 'Dalmatian' , 'height_cm': 59, 
                        'weight_kg': 25, 'date_of_birth': '2019-05-09'} ]
new_dogs = pd.DataFrame(list_of_dicts)
print(new_dogs)
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# ### Dictionary of lists - by column
#
# * **Key** = column name
# * **Value** = list of column values

# %%
import pandas as pd
dict_of_lists = { 'name': ['Ginger' , 'Scout'],
                 'breed': ['Dachshund' , 'Dalmatian'], 
                 'height_cm': [22, 59], 
                 'weight_kg': [10, 25], 
                 'date_of_birth': ['2019-03-14' , '2019-05-09'] }
new_dogs = pd.DataFrame(dict_of_lists)
print(new_dogs)
# Out:
#      name      breed  height_cm  weight_kg date_of_birth
# 0  Ginger  Dachshund         22         10    2019-03-14
# 1   Scout  Dalmatian         59         25    2019-05-09

# %% [markdown]
# ## Reading and writing CSVs

# %% [markdown]
# ### What's a CSV file?
#
# * CSV = comma-separated values
# * Designed for DataFrame-like data
# * Most database and spreadsheet programs can use them or create them

# %% [markdown]
# ### Example CSV file
#
# new_dogs.csv
# > name,breed,height_cm,weight_kg,d_o_b \
# > Ginger,Dachshund,22,10,2019-03-14 \
# > Scout,Dalmatian,59,25,2019-05-09

# %% [markdown]
# ### CSV to DataFrame

# %%
import pandas as pd
new_dogs = pd.read_csv('new_dogs.csv')

# %% [markdown]
# ### DataFrame to CSV

# %%
new_dogs.to_csv("new_dogs_with_bmi.csv")

# %% [markdown]
# # Recap
#
# * **Chapter 1**
#   * Subsetting and sorting
#   * Adding new columns
# * **Chapter 2**
#   * Aggregating and grouping
#   * Summary statistics
# * **Chapter 3**
#   * Indexing
#   * Slicing
# * **Chapter 4**
#   * Visualizations
#   * Reading and writing CSVs
