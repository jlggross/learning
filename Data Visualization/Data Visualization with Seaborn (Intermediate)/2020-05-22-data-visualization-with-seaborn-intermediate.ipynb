# %% [markdown]
# # Intermediate Data Visualization with Seaborn
#
# Link: https://learn.datacamp.com/courses/intermediate-data-visualization-with-seaborn
#
# Blog: Practical Business Python - https://pbpython.com/
#
# ## Course Agenda - What you will learn

# %% [markdown]
# ## Python Visualization Landscape
#
# ### Matplotlib
# * ```matplotlib``` provides the raw building blocks for Seaborn's
# visualizations
# * It can also be used on its own to plot data

# %%
# Using Matplotlib
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")

fig, ax = plt.subplots()
ax.hist(df['Flavanoids'])
# Out:
# (array([33., 18., 23., 20., 32., 32., 14.,  5.,  0.,  1.]),
#  array([0.34 , 0.814, 1.288, 1.762, 2.236, 2.71 , 3.184, 3.658, 4.132,
#         4.606, 5.08 ]),
#  <a list of 10 Patch objects>)

# %%
# Using pandas
import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
df['Flavanoids'].plot.hist()

# %%
# Printing DataFrame with to_markdown(). Requires 'tabulate'.
# !pip install tabulate

import pandas as pd
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
print(df.to_markdown())

# %% [markdown]
# ## Seaborn Overview
# * Seaborn supports complex visualizations of data
# * It generally does more statistical analysis on data and can provide more sophisticated insight into the data.
# * It is built on matplotlib and works best with pandas' dataframes

# %%
# Seaborn - Gaussian Kernel Density Estimate (KDE) plot
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
sns.distplot(df['Flavanoids'])
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Using the distribution plot
# * Distplot function ```distplot()``` has multiple optional arguments.
# * When used it will return a Kernel Density Estimate (KDE) by default.
#   * The KDE helps to smooth the distribution and is a useful way to look at the data.
# * In order to plot a simple histogram, you can disable the kde and
# specify the number of bins to use:
#
#     ```sns.distplot(df['alcohol'], kde=False, bins=10)```

# %%
# Distribution plot without kde on
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
sns.distplot(df['Flavanoids'], kde=False, bins=10)

# %%
# Just KDE plot
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
sns.distplot(df['Flavanoids'], hist=False, rug=True, kde_kws={'shade':True})

# %% [markdown]
# ## Regression Plots in Seaborn
# * The ```regplot``` function generates a scatter plot with a regression
# line.
# * Usage is similar to the ```distplot```.
# * The data and ```x``` and ```y``` variables must be dened.

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
sns.regplot(x="Flavanoids", y="Mg", data=df)

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
sns.lmplot(x="Flavanoids", y="Mg", data=df)
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import random

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
col_type = [random.randint(0,1) for n in range(0,df.shape[0])] # Create two groups
df['Type'] = col_type

sns.lmplot(x="Flavanoids", y="Mg", data=df, hue="Type")

# %%
import pandas as pd
import seaborn as sns
import random

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
col_type = [random.randint(0,1) for n in range(0,df.shape[0])]
df['Type'] = col_type

sns.lmplot(x="Flavanoids", y="Mg", data=df, col="Type")

# %%
import pandas as pd

# data for dataframe
data = [['Alabama', 18.8, 39, 30, 96, 80, 784.55, 145.08, 'South'],
       ['Alaska', 18.1, 41, 25, 90, 94, 1053.48, 133.93, 'West'],
       ['Arizona', 18.6, 35, 28, 84, 96, 899.47, 110.35, 'West'],
       ['Arkansas', 22.4, 18, 26, 94, 95, 827.34, 142.39, 'South'],
       ['California', 12.0, 35, 28, 91, 89, 878.41, 165.63, 'West'],
       ['Colorado', 13.6, 37, 28, 79, 95, 835.5, 139.91, 'West'],
       ['Connecticut', 10.8, 46, 36, 87, 82, 1068.73, 167.02,
        'Northeast'],
       ['Delaware', 16.2, 38, 30, 87, 99, 1137.87, 151.48, 'South'],
       ['District of Columbia', 5.9, 34, 27, 100, 100, 1273.89, 136.05,
        'South'],
       ['Florida', 17.9, 21, 29, 92, 94, 1160.13, 144.18, 'South'],
       ['Georgia', 15.6, 19, 25, 95, 93, 913.15, 142.8, 'South'],
       ['Hawaii', 17.5, 54, 41, 82, 87, 861.18, 120.92, 'West'],
       ['Idaho', 15.3, 36, 29, 85, 98, 641.96, 82.75, 'West'],
       ['Illinois', 12.8, 36, 34, 94, 96, 803.11, 139.15, 'Midwest'],
       ['Indiana', 14.5, 25, 29, 95, 95, 710.46, 108.92, 'Midwest'],
       ['Iowa', 15.7, 17, 25, 97, 87, 649.06, 114.47, 'Midwest'],
       ['Kansas', 17.8, 27, 24, 77, 85, 780.45, 133.8, 'Midwest'],
       ['Kentucky', 21.4, 19, 23, 78, 76, 872.51, 137.13, 'South'],
       ['Louisiana', 20.5, 35, 33, 73, 98, 1281.55, 194.78, 'South'],
       ['Maine', 15.1, 38, 30, 87, 84, 661.88, 96.57, 'Northeast'],
       ['Maryland', 12.5, 34, 32, 71, 99, 1048.78, 192.7, 'South'],
       ['Massachusetts', 8.2, 23, 35, 87, 80, 1011.14, 135.63,
        'Northeast'],
       ['Michigan', 14.1, 24, 28, 95, 77, 1110.61, 152.26, 'Midwest'],
       ['Minnesota', 9.6, 23, 29, 88, 88, 777.18, 133.35, 'Midwest'],
       ['Mississippi', 17.6, 15, 31, 10, 100, 896.07, 155.77, 'South'],
       ['Missouri', 16.1, 43, 34, 92, 84, 790.32, 144.45, 'Midwest'],
       ['Montana', 21.4, 39, 44, 84, 85, 816.21, 85.15, 'West'],
       ['Nebraska', 14.9, 13, 35, 93, 90, 732.28, 114.82, 'Midwest'],
       ['Nevada', 14.7, 37, 32, 95, 99, 1029.87, 138.71, 'West'],
       ['New Hampshire', 11.6, 35, 30, 87, 83, 746.54, 120.21,
        'Northeast'],
       ['New Jersey', 11.2, 16, 28, 86, 78, 1301.52, 159.85, 'Northeast'],
       ['New Mexico', 18.4, 19, 27, 67, 98, 869.85, 120.75, 'West'],
       ['New York', 12.3, 32, 29, 88, 80, 1234.31, 150.01, 'Northeast'],
       ['North Carolina', 16.8, 39, 31, 94, 81, 708.24, 127.82, 'South'],
       ['North Dakota', 23.9, 23, 42, 99, 86, 688.75, 109.72, 'Midwest'],
       ['Ohio', 14.1, 28, 34, 99, 82, 697.73, 133.52, 'Midwest'],
       ['Oklahoma', 19.9, 32, 29, 92, 94, 881.51, 178.86, 'South'],
       ['Oregon', 12.8, 33, 26, 67, 90, 804.71, 104.61, 'West'],
       ['Pennsylvania', 18.2, 50, 31, 96, 88, 905.99, 153.86,
        'Northeast'],
       ['Rhode Island', 11.1, 34, 38, 92, 79, 1148.99, 148.58,
        'Northeast'],
       ['South Carolina', 23.9, 38, 41, 96, 81, 858.97, 116.29, 'South'],
       ['South Dakota', 19.4, 31, 33, 98, 86, 669.31, 96.87, 'Midwest'],
       ['Tennessee', 19.5, 21, 29, 82, 81, 767.91, 155.57, 'South'],
       ['Texas', 19.4, 40, 38, 91, 87, 1004.75, 156.83, 'South'],
       ['Utah', 11.3, 43, 16, 88, 96, 809.38, 109.48, 'West'],
       ['Vermont', 13.6, 30, 30, 96, 95, 716.2, 109.61, 'Northeast'],
       ['Virginia', 12.7, 19, 27, 87, 88, 768.95, 153.72, 'South'],
       ['Washington', 10.6, 42, 33, 82, 86, 890.03, 111.62, 'West'],
       ['West Virginia', 23.8, 34, 28, 97, 87, 992.61, 152.56, 'South'],
       ['Wisconsin', 13.8, 36, 33, 39, 84, 670.31, 106.62, 'Midwest'],
       ['Wyoming', 17.4, 42, 32, 81, 90, 791.14, 122.04, 'West']]

# Setting columns
df = pd.DataFrame(columns=['State', 'fatal_collisions', 'fatal_collisions_speeding', 
                           'fatal_collisions_alc', 'fatal_collisions_not_distracted', 
                           'fatal_collisions_no_hist', 'premiums', 'insurance_losses', 'Region'])

# Creating rows and populating dataframe
for row_number, row_data in enumerate(data):
    df.loc[row_number] = row_data

df.to_csv('/content/drive/My Drive/Colab Notebooks/datasets/worst_drivers_US.csv')

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/worst_drivers_US.csv', index_col=0)
sns.lmplot(x="insurance_losses", y="premiums", data=df, 
           fit_reg=True, legend=True, legend_out=False,
           truncate = False,
           hue="Region") # Regression line

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/worst_drivers_US.csv', index_col=0)
sns.lmplot(x="insurance_losses", y="premiums", data=df, 
           fit_reg=True, legend=True, legend_out=False,
           truncate = False,
           hue="Region",
           col="Region") # Regression line

# %% [markdown]
# ## Using Seaborn Styles
#
# * Set default style configurations: ```sns.set()```
#   * These styles can override ```matplotlib``` and ```pandas``` plots as well
# * Set other theme styles: ```sns.set_style('style_name')```
#   * Themes: 'white', 'dark', 'whitegrid', 'darkgrid', 'ticks'
# * Removing axes: ```sns.despine(left=True)```

# %%
# Seaborn themes

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Course - Data Visualization with Seaborn (Intemediate)/wines.csv")

for style in ['white', 'dark', 'whitegrid', 'darkgrid', 'ticks']:
    sns.set_style(style)
    sns.distplot(df['Flavanoids'])
    plt.show()

# %%
# Removing axes

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")
sns.set_style('white')
sns.distplot(df['Flavanoids'])
sns.despine(left=True) # Remove left axis
plt.show()

# %% [markdown]
# ## Colors in Seaborn
# * Seaborn offers several options for modifying the colors of your visualizations. The simplest approach is to explicitly state the color of the plot.
#   * Seaborn supports assigning colors to plots using ```matplotlib``` color codes.
#     ```
#     sns.set(color_codes=True)
#     sns.distplot(df['Tuition'], color='g')
#     ```
#
# * Seaborn uses the ```set_palette()``` function to define a palette.
#   * ```sns.palettes.SEABORN_PALETTES``` has a list of different color palettes one can use.
#
# * To display a palette the function ```sns.palplot()``` can be used
#   * Using ```sns.color_palette()``` returns the current palette
#     ```
#     sns.set_palette(palette_name)
#     sns.palplot(sns.color_palette())
#     plt.show()
#     ```

# %%
# Setting plot style and showing the plot 
# Showing style palette colors

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/My Drive/Colab Notebooks/datasets/wines.csv")

for i, p in enumerate(sns.palettes.SEABORN_PALETTES, start=0):
    if i % 2 == 1:
        continue    
    sns.set_palette(p)
    sns.distplot(df['Flavanoids'])
    sns.palplot(sns.color_palette())
    plt.show()
    print("------------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------

# %%
# Setting and displaying custom color palettes

import seaborn as sns
import matplotlib.pyplot as plt

sns.palplot(sns.color_palette("Paired", 20))
plt.show()

sns.palplot(sns.color_palette("Blues", 12))
plt.show()

sns.palplot(sns.color_palette("BrBG", 8))
plt.show()

# %% [markdown]
# ## Customizing with matplotlib
#
# * Matplotlib Axes
# ```
# fig, ax = plt.subplots()
# sns.distplot(df['Tuition'], ax=ax)
# ax.set(xlabel="Tuition 2013-14",
#        ylabel="Distribution", xlim=(0, 50000),
#        title="2013-14 Tuition and Fees Distribution")
# ```

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/worst_drivers_US.csv', index_col=0)

fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, 
                               sharey=True, figsize=(7,4))

# First plot
sns.distplot(df['insurance_losses'], ax=ax0, color='r')
ax0.set(xlabel="Insurance Losses (All Regions)", xlim=(50, 250))

# Second plot
sns.distplot(df.query('Region == "South"')['insurance_losses'], ax=ax1, color='g')
ax1.set(xlabel="Insurance Losses (South)", xlim=(50, 250))
ax1.axvline(x=150, label='My Loss', linestyle='--', linewidth=2)
ax1.legend()

plt.show()

# %% [markdown]
# # Categorical Plot Types
#
# * Data which takes on a limited and fixed number of values
# * Normally combined with numeric data
#
# ## Plot types
# * ```stripplot()```
# * ```swarmplot()```
# * ```boxplot()```
# * ```violinplot()```
# * ```lvplot()``` -> New function name: ```boxenplot()```
# * ```barplot()```
# * ```pointplot()```
# * ```countplot()```

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("white")
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/schoolimprovement2010grants.csv', index_col=0)

# %%
sns.stripplot(data=df, x='Award_Amount', y='Model Selected',
              jitter=True)
plt.show()

# %%
sns.swarmplot(data=df, x='Award_Amount', y='Model Selected',
              hue='Region')
plt.show()

# %%
sns.boxplot(data=df, x='Award_Amount', y='Model Selected')
plt.show()

# %%
sns.violinplot(data=df, x='Award_Amount', y='Model Selected',
         palette='husl')
plt.show()

# %%
sns.boxenplot(data=df, x='Award_Amount', y='Model Selected',
           palette='Paired',
           hue='Region')
plt.show()

# %%
sns.countplot(data=df, y="Model Selected",
              hue="Region")
plt.show()

# %%
sns.pointplot(data=df, y='Award_Amount', x='Model Selected',
         capsize=.1)
plt.show()

# %%
sns.barplot(data=df, y='Award_Amount', x='Model Selected',
            hue='Region')
plt.show()

# %% [markdown]
# # Regression Plots
#
# * ```regplot()```: Regression plot
#   * ```order``` parameter is used to set the order of the polynomial regression
#   * ```x_estimator``` parameter can be useful for highlighting trends
#     * Provides simplified view
# * ```residplot()```: Residual plot
#   * A residual plot is useful for evaluating the fit of a model

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#sns.set_style("white")
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/bike_share.csv')

# %%
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1,ncols=3, sharey=True, figsize=(12,4))

sns.regplot(data=df, x='temp', y='total_rentals', marker='+', ax=ax0)

# Polynomial regression using the 'order' parameter
sns.regplot(data=df, x='temp', y='total_rentals', order=2, color='r', ax=ax1)
sns.regplot(data=df, x='temp', y='total_rentals', order=2, color='g', 
            fit_reg=False, ax=ax2)
plt.show()

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,3))

sns.residplot(data=df, x='temp', y='total_rentals', color='b', ax=ax0)

# Polynomial regression with 'order'
sns.residplot(data=df, x='temp', y='total_rentals', order=2, color='y', ax=ax1)
plt.show()

# %%
# Easier to see the distribution of rentals in each month
fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(10,3))
sns.regplot(data=df, x='mnth', y='total_rentals', 
            x_jitter=.1, order=2, ax=ax0)
sns.regplot(data=df, x='mnth', y='total_rentals', order=2, ax=ax1)
plt.show()

# %%
# Estimator
import numpy as np

fig, (ax0, ax1, ax2) = plt.subplots(nrows=1,ncols=3, sharey=True, figsize=(10,3))
sns.regplot(data=df, x='mnth', y='total_rentals',
            x_estimator=np.mean, order=2, ax=ax0)
sns.regplot(data=df, x='mnth', y='total_rentals',
            x_estimator=np.median, order=2, ax=ax1)
sns.regplot(data=df, x='mnth', y='total_rentals',
            x_estimator=np.max, order=2, ax=ax2)
plt.show()

# %%
# Selecting number of bins
fig, (ax0, ax1, ax2) = plt.subplots(nrows=1,ncols=3, sharey=True, figsize=(10,3))
sns.regplot(data=df, x='temp', y='total_rentals', x_bins=4, ax=ax0)
sns.regplot(data=df, x='temp', y='total_rentals', x_bins=8, ax=ax1)
sns.regplot(data=df, x='temp', y='total_rentals', x_bins=12, order=3, ax=ax2)
plt.show()

# %% [markdown]
# # Matrix plots
#
# * ```heatmap()``` is the most type of matrix plot.
#   * Requires data to be in a grid format.
# * Matrix plots can be used to quicky see trends in a dataset
#
# ## Customize heatmap() function
# * ```annot=True```: Turn on annotations in the indiividual cells.
# * ```fmt="d"```: Uses formating to show values as integers.
# * ```fmt=".1f"```: Uses formating to show values as floats with one decimal number.
# * ```cmap```: Parameter used to change the shading used in the plot.
# * ```cbar=False```: The color bar is not displayed.
# * ```linewidths=0.5```: Puts a small space between cells, so that the values are simpler to view.
# * ```center=1000```: Center the color scheme of the heatmap to the value 1000.
#
# ## Plotting a correlation matrix
# * Pandas ```corr``` function calculates correlations between columns in a dataframe
# * The output can be converted to a heatmap with seaborn
#
#     ```sns.heatmap(df.corr())```

# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/bike_share.csv')

# %%
# Create table to be used in the heatmap
heatmap_matrix = pd.crosstab(df["mnth"], df["weekday"],
            values=df["total_rentals"],aggfunc='mean').round(0)
print(heatmap_matrix)
# Out:
# weekday       0       1       2       3       4       5       6
# mnth
# 1        1816.0  1927.0  2568.0  2139.0  2513.0  2446.0  1957.0
# 2        2248.0  2604.0  2824.0  2813.0  2878.0  2933.0  2266.0
# 3        3301.0  3546.0  3574.0  3670.0  3817.0  3926.0  3939.0
# 4        4417.0  4516.0  4556.0  4331.0  4764.0  4387.0  4446.0
# 5        5320.0  4512.0  5025.0  5119.0  5893.0  5751.0  5978.0
# 6        5940.0  5478.0  5681.0  5701.0  5622.0  5616.0  6344.0
# 7        5298.0  5792.0  5844.0  5814.0  5624.0  5406.0  5232.0
# 8        4703.0  5518.0  5930.0  6077.0  6038.0  5958.0  5224.0
# 9        6160.0  5637.0  5184.0  5668.0  5486.0  5747.0  6394.0
# 10       4735.0  4632.0  5065.0  5505.0  5537.0  5623.0  5445.0
# 11       4126.0  4658.0  4040.0  4136.0  3994.0  4524.0  4288.0
# 12       2740.0  3498.0  3713.0  3270.0  3711.0  3742.0  3195.0

# %%
sns.heatmap(heatmap_matrix)

# %%
# Customizing heatmap
sns.heatmap(heatmap_matrix, annot=True, fmt=".0f",
            cmap="YlGnBu", cbar=False, linewidths=.5)

# %%
sns.heatmap(heatmap_matrix, annot=True, fmt=".0f", 
            cmap="YlGnBu", cbar=True, 
            center=heatmap_matrix.loc[9, 6])

# %%
sns.heatmap(df.corr())

# %%
daily_show_df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/daily_show_guests_cleaned.csv')

pd_crosstab = pd.crosstab(daily_show_df["Group"], daily_show_df["YEAR"])
sns.heatmap(pd_crosstab)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

sns.heatmap(pd_crosstab, cbar=False, cmap="BuGn", linewidths=.3)
plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Using FacetGrid, factorplot and lmplot
#
# * Multiple smaller plots can build a larger visualization that can help identy trends in data with manu variables.
# * The concept of small multiples is useful for analysing data with many variables.
# * The idea is that you can quickly identify trends in data by comparing multiple plots side by side using the same scales and axes.
#   * This process is called **faceting**.
#
# ## Facegrid
# * The ```FacetGrid``` is foundational for many data-aware grids.
# * A data-aware grid allows you to create a series of small plots that can be useful for understanding complex data relationships.
# * It allows the user to control how data is distributed across columns,
# rows and hue.
# * When building a FacetGrid, there are two steps:
#   1. Create a ```FacetGrid``` object with columns, rows, or hue.
#   2. Map individual plots to the grid.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set_style("white")
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/2018 College Scorecard Tuition.csv', index_col=0)

# %%
g = sns.FacetGrid(df, col="HIGHDEG", col_order=[2, 1, 4, 3])
g.map(sns.boxplot, "Tuition")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:723: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Create a FacetGrid varying by column and columns ordered with the degree_order variable
degree_ord = ['Bachelors', 'Graduate', 'Associates']
g = sns.FacetGrid(df, col="Degree_Type", col_order=degree_ord, height=7)

# Map a scatter plot of Undergrad Population compared to PCTPELL
g.map(plt.scatter, 'UG', 'PCTPELL')

plt.show()

# %% [markdown]
# ## ```catplot()```
# * The ```catplot``` function is a simpler way to use a FacetGrid for
# categorical data
# * Combines the facetting and mapping process into one function

# %%
g = sns.catplot(x='Tuition', 
                data=df,
                col="HIGHDEG",
                kind='box',
                col_order=[2, 3, 1, 4])

# %% [markdown]
# ## FacetGrid for regression
# * ```FacetGrid()``` can also be used for scatter or regression plots.

# %%
g = sns.FacetGrid(df, col="HIGHDEG", col_order=[3, 1, 2, 4])
g.map(plt.scatter, 'Tuition', 'SAT_AVG_ALL')

# %% [markdown]
# ## lmplot
# * ```lmplot``` plots scatter and regression plots on a ```FacetGrid```

# %%
sns.lmplot(data=df, x="Tuition", y="SAT_AVG_ALL", 
           col="HIGHDEG", col_order=[1, 2, 3, 4],
           fit_reg=False)

# %%
sns.lmplot(data=df,
        x='UG',
        y='PCTPELL',
        col="Degree_Type",
        col_order=degree_ord,
        height=5)

plt.show()

# %%
# Create an lmplot that has a column for Ownership, a row for Degree_Type and hue based on the WOMENONLY column
sns.lmplot(data=df,
        x='SAT_AVG_ALL',
        y='Tuition',
        col="Ownership",
        row='Degree_Type',
        row_order=['Graduate', 'Bachelors'],
        hue='WOMENONLY',
        col_order=['Public', 'Private non-profit'],
        height=4)
plt.show()

# %% [markdown]
# # Using PairGrid and pairplot
# * Allow us to see interactions across different columns of data.
# * ```PairGrid``` shows **pairwise relationships** between data elements.
#
# ## Creating a ```PairGrid```
# 1. Create ```PairGrid```.
# 2. Map plot to the grid.
#
# ## Pairplot
# * ```pairplot``` is a shortcut for the PairGrid.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set_style("white")
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/US Housing and Urban Development FY 2018 Fair Market Rent.csv', index_col=0)

df.head(3)
# Out:
#            fmr_0  fmr_1  fmr_2  ...  metro  fmr_pct_chg  fmr_dollar_chg
# fips2010                        ...
# 100199999    588    691    829  ...      1     0.008516               7
# 100399999    729    762    879  ...      1    -0.100307             -98
# 100599999    491    494    657  ...      0    -0.020864             -14
#
# [3 rows x 19 columns]

# %%
g = sns.PairGrid(df, vars=["fmr_0", "fmr_4"])
g = g.map(plt.scatter)

# %%
# Customizing the PairGrid diagonals - map_diag and map_offdiag
g = sns.PairGrid(df, vars=["fmr_0", "fmr_4"])
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
# Using pairplot
sns.pairplot(df, vars=["fmr_0", "fmr_4"], 
             kind='reg', diag_kind='hist')

# %%
# Customizing a pairplot
sns.pairplot(df.query('state < 5'),
             vars=["fmr_0", "fmr_2", "fmr_4"],
             hue='state', palette='husl',
plot_kws={'alpha': 0.5})

# %%
# Car insurance x collisions data
df2 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/worst_drivers_US.csv')
print(df2.head())

sns.pairplot(data=df2,
        vars=["fatal_collisions", "premiums"],
        kind='scatter',
        hue='Region',
        palette='RdBu',
        diag_kws={'alpha':.5})
# Out:
#    Unnamed: 0       State  fatal_collisions  ...  premiums  insurance_losses  Region
# 0           0     Alabama              18.8  ...    784.55            145.08   South
# 1           1      Alaska              18.1  ...   1053.48            133.93    West
# 2           2     Arizona              18.6  ...    899.47            110.35    West
# 3           3    Arkansas              22.4  ...    827.34            142.39   South
# 4           4  California              12.0  ...    878.41            165.63    West
#
# [5 rows x 10 columns]

# %%
# Build a pairplot with different x and y variables
sns.pairplot(data=df2,
        x_vars=["fatal_collisions_speeding", "fatal_collisions_alc"],
        y_vars=['premiums', 'insurance_losses'],
        kind='scatter',
        hue='Region',
        palette ='husl')

# %%
# plot relationships between insurance_losses and premiums
# kind : non-diagonal plot
# diag_king : diagonal plot
sns.pairplot(data=df2,
             vars=["insurance_losses", "premiums"],
             kind='reg',
             palette='BrBG',
             diag_kind = 'kde',
             hue='Region')

# %% [markdown]
# # Using JointGrid and jointplot
# * A ```JointGrid()``` allows us to compare the distribution of data beteween two variables.
#   * ```JointGrid()``` combines univariate plots such as histograms, rug plots and kde plots with bivariate plots such as scatter and regression plots.
# * Takes a small number of inputs and creates an insightful visualization of the data.
# * Layout basics of a ```JointGrid()```:
#   * The input to ```JointGrid()``` is an X and Y variable.
#   * The center of the plot contains a plot type, for example, a scatter plot of these two variables.
#   * The plots along the x and y-axis show the distribution of the data for each variable.
#   * This plot can be configured by specifying the type of joint plots as well as the marginal plots.
#
# ## ```jointplot()```
# * It is easier to use but provides fewer customization capabilities.
# * The jointplot is a convenience wrapper around many of the ```JointGrid``` functions.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set_style("white")
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/2018 College Scorecard Tuition.csv', index_col=0)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Basic JointGrid
g = sns.JointGrid(data=df, x="Tuition", y="ADM_RATE_ALL")
g.plot(sns.regplot, sns.distplot)

# %%
# Advanced JoinGrid
g = sns.JointGrid(data=df, x="Tuition", y="ADM_RATE_ALL", 
                  xlim=(0, 45000), ylim=(0.2, 1.2))

#color_map_palette = sns.dark_palette("palegreen", as_cmap=True)
color_map_palette = sns.light_palette("green", as_cmap=True)
#color_map_palette = "Blues_d"
#color_map_palette = "Reds_d"
#color_map_palette = "Purples_d"
g = g.plot_joint(sns.kdeplot, 
                 cmap=color_map_palette,
                 n_levels=8)

#g = g.plot_marginals(sns.kdeplot, c='g', shade=True)
g = g.plot_marginals(sns.distplot, color='g')

# %%
# Advanced JoinGrid
g = sns.JointGrid(data=df, x="Tuition", y="ADM_RATE_ALL", 
                  xlim=(0, 45000), ylim=(0.2, 1.2))
color_map_palette = sns.light_palette("blue", as_cmap=True)
g = g.plot_joint(sns.kdeplot, 
                 cmap=color_map_palette,
                 n_levels=8,
                 shade=True)
g = g.plot_marginals(sns.kdeplot, color='blue', shade=True)

# %%
# Customizing JointGrid()
import numpy as np
g = sns.JointGrid(data=df, x="Tuition", y="ADM_RATE_ALL")

g = g.plot_joint(sns.scatterplot, color='green', alpha=0.6)
_ = g.ax_marg_x.hist(df['Tuition'], color="red", alpha=.6,
                     bins=np.arange(0, 50000, 5000))
_ = g.ax_marg_y.hist(df['ADM_RATE_ALL'], color="blue", alpha=.6,
                     orientation="horizontal",
                     bins=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Using joinplot()
import scipy.stats as stats
g = sns.jointplot(data=df, x='Tuition', 
              y='ADM_RATE_ALL', kind='hex')
g.annotate(stats.pearsonr)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# Customizing a jointplot - with overlay plots
import scipy.stats as stats
g = (sns.jointplot(x='Tuition', y='ADM_RATE_ALL', 
                   kind='scatter', 
                   xlim=(0, 25000), 
                   marginal_kws=dict(bins=15, rug=True), 
                   data=df.query('UG < 2500 & Ownership == "Public"'))
    .plot_joint(sns.kdeplot))
g.annotate(stats.pearsonr)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

sns.set_style("white")
bike_rental = pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/bike_share.csv', index_col=0)

# Relationship between humidity and rental amounts
g = sns.jointplot(x="temp", y="total_rentals",
         kind='reg', data=bike_rental, order=2, 
         truncate=False, xlim=(0, 1))
g.annotate(stats.pearsonr)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# Plot of the residuals of the relationship between humidity and rental amounts
sns.jointplot(x="temp",
        y="total_rentals",
        kind='resid',
        data=bike_rental,
        order=2)

# %%
# Temp vs. registered riders, including a kdeplot over the scatter plot
g = (sns.jointplot(x="temp",
             y="registered",
             kind='scatter',
             data=df,
             marginal_kws=dict(bins=10, rug=True))
    .plot_joint(sns.kdeplot))

# %% [markdown]
# # When to use each plot
#
# ## Univariate Distribution Analysis
# * ```distplot()``` is the best place to start for this analysis
#   * Is the best place to start when trying to do distribution analysis with Seaborn.
#   * Combines many of the features of the ```rugplot()```, ```kdeplot()```, and matplotlib histogram into a single function.
#   * Can be used to generated kdeplot plot.
# * ```rugplot()``` and ```kdeplot()``` can be useful alternatives
#
# ## Regression Analysis
# A regression plot is an example of a plot that shows the relationship between two variables.
#
# * matplotlib's ```scatter()``` plot is a very simple method to compare the interaction of two variables on the x and y-axis.
# * ```lmplot()``` performs regression analysis and supports facetting.
#   * The ```lmplot()``` combines many of these features of the underlying ```regplot()``` and ```residplot()``` in addition to the ability to plot the data on a ```FacetGrid()```.
#   * Is the best function, in many instances, to use for determining linear relationships between data.
#
# ## Categorical Plots
# Explore data with the categorical plots and facet with
#
# * ```boxplot()``` or ```violinplot()``` can be used to examine the distribution of the variables.
#   * Can be combined with the statistical estimation plots such as the point, bar, or countplot.
# * To facet the data across rows or columns we use ```factorplot()```.
#
# ## pairplot() and jointplot()
# * ```PairGrid()``` and ```JointGrid()```: useful visualizations after some preliminary analysis of regressions or distributions of the data has already been done.
#   * Perform regression analysis with ```lmplot```.
#   * Analyze distributions with ```distplot```.
# * After being familiar with the data, the ```pairplot()``` and ```jointplot()``` can be used to understand how two or more variables interact with each other.
