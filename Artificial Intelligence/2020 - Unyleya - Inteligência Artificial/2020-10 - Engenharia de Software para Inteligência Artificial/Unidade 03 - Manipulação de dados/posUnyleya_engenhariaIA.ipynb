# %% [markdown]
# # Tarefa Unidade 03 - Manipulação de dados
#
# * **Disciplina**: Engenharia de Software para Inteligência Artificial
# * **Aluno:** João Luiz Grave Gross
# * **Data de entrega:** 05-10-2020

# %% [markdown]
# ## Enunciado
#
# 1. Criar uma planilha com o conteúdo de sua preferência, mas seguindo alguns requisitos, a planilha de ter entre 8 e 12 colunas, e deve ter entre 80 e 200 linhas.
# 2. Executar os comandos abaixo e reportar as saídas: \
#   2.1. Por meio de um notebook importar a biblioteca Pandas, import pandas as pd”; \
#   2.2. Com a planilha salva em uma pasta conhecida do seu computador leia os dados para uma variável chamada `df`; \
#   2.3. Ler as 5 primeiras e as 3 últimas linhas da planilha com usando os métodos `head` e `tail` do Pandas; \
#   2.4. Descubra o método que nos mostra um relatório resumido da nossa planilha, neste momento, do nosso data frame e anote a saída em seu relatório; \
#   2.5. Agora vamos adicionar o próprio data frame a atual data frame, e vamos conferir que seu tamanho realmente duplicou como de esperado, após relatar isso, podemos eliminar as duplicações, dica de comando, vejam: append, shape e drop_duplicates; \
#   2.6. Imprima os nomes atuais das colunas, com o comando columns, e depois renomear algumas destas colunas, com o comando rename, e imprimir novamente os nomes das colunas para termos a certeza que foram alterados com o comando da forma que queríamos; \
#   2.7. Agora seguindo a apostila acrescente mais três comandos usando métodos do Pandas e anote as saídas no relatório que deverá ser enviado nesta tarefa.

# %%
import pandas as pd # item 2.1

df = pd.read_csv("/content/automobiles.csv") # item 2.2

print(df.head(5)) # item 2.3
print(df.tail(3)) # item 2.3
# Out:
#     mpg  cyl  displ   hp  ...  accel          yr origin                       name
# 0  18.0    8  307.0  130  ...   12.0  1970-01-01     US  chevrolet chevelle malibu
# 1  15.0    8  350.0  165  ...   11.5  1970-01-01     US          buick skylark 320
# 2  18.0    8  318.0  150  ...   11.0  1970-01-01     US         plymouth satellite
# 3  16.0    8  304.0  150  ...   12.0  1970-01-01     US              amc rebel sst
# 4  17.0    8  302.0  140  ...   10.5  1970-01-01     US                ford torino
#
# [5 rows x 9 columns]
#       mpg  cyl  displ  hp  weight  accel          yr origin           name
# 389  32.0    4  135.0  84    2295   11.6  1982-01-01     US  dodge rampage
# 390  28.0    4  120.0  79    2625   18.6  1982-01-01     US    ford ranger
# 391  31.0    4  119.0  82    2720   19.4  1982-01-01     US     chevy s-10

# %%
df.info() # item 2.4 - Relatório sobre DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     392 non-null    float64
#  1   cyl     392 non-null    int64
#  2   displ   392 non-null    float64
#  3   hp      392 non-null    int64
#  4   weight  392 non-null    int64
#  5   accel   392 non-null    float64
#  6   yr      392 non-null    object
#  7   origin  392 non-null    object
#  8   name    392 non-null    object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 27.7+ KB

# %%
df.describe() # item 2.4 - Relatório sobre DataFrame
# Out:
#               mpg         cyl       displ          hp       weight       accel
# count  392.000000  392.000000  392.000000  392.000000   392.000000  392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184   15.541327
# std      7.805007    1.705783  104.644004   38.491160   849.402560    2.758864
# min      9.000000    3.000000   68.000000   46.000000  1613.000000    8.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000   13.775000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000   15.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000   17.025000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000   24.800000

# %%
# item 2.5
print(df.shape)
df = df.append(df)
print(df.shape)
df = df.drop_duplicates()
print(df.shape)
# Out:
# (392, 9)
# (784, 9)
# (392, 9)

# %%
# item 2.6
print(df.columns)
df = df.rename(columns={
    'mpg':'novonome',
    'cyl':'outronome'
})
print(df.columns)
# Out:
# Index(['mpg', 'cyl', 'displ', 'hp', 'weight', 'accel', 'yr', 'origin', 'name'], dtype='object')
# Index(['novonome', 'outronome', 'displ', 'hp', 'weight', 'accel', 'yr',
#        'origin', 'name'],
#       dtype='object')

# %%
# item 2.7
print(df['yr'].unique()) # comando 1
print("\n")

df2 = df.copy() # comando 2
print(df2.head())
print("\n")

df.plot(x='novonome', y='accel') # comando 3
# Out:
# ['1970-01-01' '1971-01-01' '1972-01-01' '1973-01-01' '1974-01-01'
#  '1975-01-01' '1976-01-01' '1977-01-01' '1978-01-01' '1979-01-01'
#  '1980-01-01' '1981-01-01' '1982-01-01']
#
#
#    novonome  outronome  displ  ...          yr  origin                       name
# 0      18.0          8  307.0  ...  1970-01-01      US  chevrolet chevelle malibu
# 1      15.0          8  350.0  ...  1970-01-01      US          buick skylark 320
# 2      18.0          8  318.0  ...  1970-01-01      US         plymouth satellite
# 3      16.0          8  304.0  ...  1970-01-01      US              amc rebel sst
# 4      17.0          8  302.0  ...  1970-01-01      US                ford torino
#
# [5 rows x 9 columns]
